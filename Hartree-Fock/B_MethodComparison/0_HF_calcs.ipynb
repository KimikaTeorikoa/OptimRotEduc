# %% [markdown]
# # Hartree-Fock: Comparison of optimization algorithms at Best Learning Rate

# %% [markdown]
# Import libreries

# %%
import csv
import pynof
import numpy as np
from scipy.linalg import eigh
import sys
# Define energy.py path, in our case is in myCode dir, two directories above
sys.path.insert(1, '../../myCode/')
# read files with optimization functions
from energy import *

# %% [markdown]
# Create molecule and choose basis set

# %%
#Molecules Definition
#Times given in Seconds, gotten on a Linux PC (12th Gen Intel(R) Core(TM) i9-12900K)
#with export OMP_NUM_THREADS=8

# Molecules coordinates
#time = 267 (all BF3 notebook)
bf3 = pynof.molecule("""
0 1
 F     4.007177     0.908823     0.000000
 F     1.724922     0.908844     0.000000
 F     2.866001    -1.067658    -0.000000
 B     2.866001     0.249991    -0.000000 
""")

#time = 910 all chcl3 notebook
chcl3 = pynof.molecule("""
  0 1
Cl        -0.09620       -1.67890        0.13940
Cl        -1.40590        0.92280        0.13940
Cl         1.50220        0.75610        0.13930
C         -0.00010        0.00000       -0.41810
H         -0.00010       -0.00010       -1.51110
""")

#time = 823 all al(oh)_3 notebook
aloh = pynof.molecule("""
0 1
Al     0.072995     0.126285    -0.072819
 O    -0.117348     0.068538     1.623683
 O     1.640841     0.345700    -0.695473
 O    -1.181058    -0.017712    -1.213874
 H     2.443051     0.441622    -0.181373
 H    -0.892422    -0.042102     2.172874
 H    -2.121611    -0.146659    -1.103014
""")

# Dictionary to facilitate molecule selection with 
# output file name

molecules = {
    "bf3": bf3,
    "chcl3": chcl3,
    "aloh": aloh,
}

#########
# USER ACTION REQUIRED
# Select molecule 
molecule = "aloh" # or "aloh" or chcl3
#########
mol = molecules[molecule]

# Select basis set
basis = "cc-pvdz"

p = pynof.param(mol,basis)
# Out:
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry AL         line   418 file /Users/pobmelat/miniconda3/envs/newConda/share/psi4/basis/cc-pvdz.gbs
#     atoms 2-4 entry O          line   198 file /Users/pobmelat/miniconda3/envs/newConda/share/psi4/basis/cc-pvdz.gbs
#     atoms 5-7 entry H          line    22 file /Users/pobmelat/miniconda3/envs/newConda/share/psi4/basis/cc-pvdz.gbs

# %% [markdown]
# We run the optimization using SD, CG, RMSProp, ADAGRAD and ADAM at the best leraning rate values for comparison. The optimization data is written into a csv files.

# %%
algorithms = [ 'SD', 'CG', 'RMSPROP', 'ADAGRAD', 'ADAM' ]
#all_energy_data = {}  # Dictionary to store results for each alpha
p.alpha = 0.02
# File name to store the data
filename = f"{molecule}.csv"

with open(filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["alg", "iteration", "energy"])  # Header

    for alg in algorithms:
        p.orb_method=alg
        if alg == 'SD':
           p.alpha = 0.02
        if alg == 'CG':
           p.alpha = 0.02
        elif alg == 'ADAGRAD':
           p.alpha = 0.08
        elif alg == 'RMSPROP':
           p.alpha = 0.002
        elif alg == 'ADAM':
           p.alpha = 0.02           
        _, energy_data = calc_hf_orbrot(mol, p)
        for i_ext, energy in energy_data:
            writer.writerow([alg, i_ext, energy])
# Out:
# Number of basis functions                   (NBF)    = 75
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 20
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 2
# Dimension of the Nat. Orb. subspace         (NBF5)   = 60
# No. of electrons                                     = 40
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# HF Calculation (SD Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.02
# Starting SD ... with alpha 0.02
#      0     30      0    -628.63473257  -467.92312463 -10627.63473257      5.7e+00    0.0e+00   False   True
# alpha =  0.02
# Starting SD ... with alpha 0.02
#      1     30      0    -628.63473257  -467.92312463      0.00000000      5.7e+00    0.0e+00   False   True
# alpha =  0.02
# Starting SD ... with alpha 0.02
#      2     30      0    -628.63473257  -467.92312463      0.00000000      5.7e+00    0.0e+00   False   True
# alpha =  0.02
# Starting SD ... with alpha 0.02
#      3     30      0    -628.63473257  -467.92312463      0.00000000      5.7e+00    0.0e+00   False   True
# alpha =  0.02
# Starting SD ... with alpha 0.02
#      4     30      0    -628.63473257  -467.92312463      0.00000000      5.7e+00    0.0e+00   False   True
# alpha =  0.02
# Starting SD ... with alpha 0.02
#      5     30      0    -628.63473257  -467.92312463      0.00000000      5.7e+00    0.0e+00   False   True
#
#
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
# !!!! Energy is not converging, if you are playing with alpha, is not a good value
# !!!! In any case check orbital and occupation gradients
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
#
#
#
# Lagrage sumdiff 3.2e+01 maxfdiff 4.8e-01
#
# RESULTS OF THE OCCUPATION OPTIMIZATION
# ========================================
#  Idx        n        E (Hartree)
#    1    2.0000000  -32.73236231
#    2    2.0000000  -22.15656632
#    3    2.0000000  -22.04108702
#    4    2.0000000  -21.90423834
#    5    2.0000000   -7.57349099
#    6    2.0000000   -6.90711273
#    7    2.0000000   -6.89250342
#    8    2.0000000   -5.49890444
#    9    2.0000000   -3.01520641
#   10    2.0000000   -3.00790304
#   11    2.0000000   -2.99346030
#   12    2.0000000   -1.23090438
#   13    2.0000000   -1.14518786
#   14    2.0000000   -0.99262245
#   15    2.0000000   -0.64788298
#   16    2.0000000   -0.63758718
#   17    2.0000000   -0.60725994
#   18    2.0000000   -0.44518102
#   19    2.0000000   -0.43761143
#   20    2.0000000   -0.42095657
#   21    0.0000000    0.00000000
#   22    0.0000000    0.00000000
#   23    0.0000000    0.00000000
#   24    0.0000000    0.00000000
#   25    0.0000000    0.00000000
#   26    0.0000000    0.00000000
#   27    0.0000000    0.00000000
#   28    0.0000000    0.00000000
#   29    0.0000000    0.00000000
#   30    0.0000000    0.00000000
#   31    0.0000000    0.00000000
#   32    0.0000000    0.00000000
#   33    0.0000000    0.00000000
#   34    0.0000000    0.00000000
#   35    0.0000000    0.00000000
#   36    0.0000000    0.00000000
#   37    0.0000000    0.00000000
#   38    0.0000000    0.00000000
#   39    0.0000000    0.00000000
#   40    0.0000000    0.00000000
#   41    0.0000000    0.00000000
#   42    0.0000000    0.00000000
#   43    0.0000000    0.00000000
#   44    0.0000000    0.00000000
#   45    0.0000000    0.00000000
#   46    0.0000000    0.00000000
#   47    0.0000000    0.00000000
#   48    0.0000000    0.00000000
#   49    0.0000000    0.00000000
#   50    0.0000000    0.00000000
#   51    0.0000000    0.00000000
#   52    0.0000000    0.00000000
#   53    0.0000000    0.00000000
#   54    0.0000000    0.00000000
#   55    0.0000000    0.00000000
#   56    0.0000000    0.00000000
#   57    0.0000000    0.00000000
#   58    0.0000000    0.00000000
#   59    0.0000000    0.00000000
#   60    0.0000000    0.00000000
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy = {E_nuc + E:15.7f}
#
#
# Elapsed Time:     118.07 (Seconds)
# True
# Number of basis functions                   (NBF)    = 75
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 20
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 2
# Dimension of the Nat. Orb. subspace         (NBF5)   = 60
# No. of electrons                                     = 40
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# HF Calculation (CG Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.02
# Starting CG ... with alpha 0.02
#      0     30      0    -619.77815951  -459.06655157 -10618.77815951      3.2e+01    0.0e+00   False   True
# alpha =  0.02
# Starting CG ... with alpha 0.02
#      1     30      0    -619.77815951  -459.06655157      0.00000000      3.2e+01    0.0e+00   False   True
# alpha =  0.02
# Starting CG ... with alpha 0.02
#      2     30      0    -619.77815951  -459.06655157      0.00000000      3.2e+01    0.0e+00   False   True
# alpha =  0.02
# Starting CG ... with alpha 0.02
#      3     30      0    -619.77815951  -459.06655157      0.00000000      3.2e+01    0.0e+00   False   True
# alpha =  0.02
# Starting CG ... with alpha 0.02
#      4     30      0    -619.77815951  -459.06655157      0.00000000      3.2e+01    0.0e+00   False   True
# alpha =  0.02
# Starting CG ... with alpha 0.02
#      5     30      0    -619.77815951  -459.06655157      0.00000000      3.2e+01    0.0e+00   False   True
#
#
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
# !!!! Energy is not converging, if you are playing with alpha, is not a good value
# !!!! In any case check orbital and occupation gradients
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
#
#
#
# Lagrage sumdiff 1.0e+02 maxfdiff 6.8e+00
#
# RESULTS OF THE OCCUPATION OPTIMIZATION
# ========================================
#  Idx        n        E (Hartree)
#    1    2.0000000  -57.41190441
#    2    2.0000000  -18.09462593
#    3    2.0000000  -18.07318213
#    4    2.0000000  -18.05183328
#    5    2.0000000   -4.77699441
#    6    2.0000000   -3.08941057
#    7    2.0000000   -3.06905985
#    8    2.0000000   -3.06282497
#    9    2.0000000    0.13633891
#   10    2.0000000    0.15417900
#   11    2.0000000    0.16927712
#   12    2.0000000    0.18213445
#   13    2.0000000    0.20624934
#   14    2.0000000    0.24620615
#   15    2.0000000    0.60311473
#   16    2.0000000    0.61583261
#   17    2.0000000    0.62934357
#   18    2.0000000    0.75092929
#   19    2.0000000    0.76907030
#   20    2.0000000    0.79332574
#   21    0.0000000    0.00000000
#   22    0.0000000    0.00000000
#   23    0.0000000    0.00000000
#   24    0.0000000    0.00000000
#   25    0.0000000    0.00000000
#   26    0.0000000    0.00000000
#   27    0.0000000    0.00000000
#   28    0.0000000    0.00000000
#   29    0.0000000    0.00000000
#   30    0.0000000    0.00000000
#   31    0.0000000    0.00000000
#   32    0.0000000    0.00000000
#   33    0.0000000    0.00000000
#   34    0.0000000    0.00000000
#   35    0.0000000    0.00000000
#   36    0.0000000    0.00000000
#   37    0.0000000    0.00000000
#   38    0.0000000    0.00000000
#   39    0.0000000    0.00000000
#   40    0.0000000    0.00000000
#   41    0.0000000    0.00000000
#   42    0.0000000    0.00000000
#   43    0.0000000    0.00000000
#   44    0.0000000    0.00000000
#   45    0.0000000    0.00000000
#   46    0.0000000    0.00000000
#   47    0.0000000    0.00000000
#   48    0.0000000    0.00000000
#   49    0.0000000    0.00000000
#   50    0.0000000    0.00000000
#   51    0.0000000    0.00000000
#   52    0.0000000    0.00000000
#   53    0.0000000    0.00000000
#   54    0.0000000    0.00000000
#   55    0.0000000    0.00000000
#   56    0.0000000    0.00000000
#   57    0.0000000    0.00000000
#   58    0.0000000    0.00000000
#   59    0.0000000    0.00000000
#   60    0.0000000    0.00000000
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy = {E_nuc + E:15.7f}
#
#
# Elapsed Time:     115.05 (Seconds)
# True
# Number of basis functions                   (NBF)    = 75
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 20
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 2
# Dimension of the Nat. Orb. subspace         (NBF5)   = 60
# No. of electrons                                     = 40
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# HF Calculation (RMSPROP Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.002
#      0     30      0    -619.22328570  -458.51167776 -10618.22328570      1.1e+01    0.0e+00   False   True
# alpha =  0.002
#      1     30      0    -624.23527197  -463.52366403     -5.01198627      7.3e+00    0.0e+00   False   True
# alpha =  0.002
#      2     30      0    -626.66619000  -465.95458206     -2.43091803      5.2e+00    0.0e+00   False   True
# alpha =  0.002
#      3     30      0    -628.05313486  -467.34152692     -1.38694487      4.1e+00    0.0e+00   False   True
# alpha =  0.002
#      4     30      0    -628.75548667  -468.04387873     -0.70235181      3.1e+00    0.0e+00   False   True
# alpha =  0.002
#      5     30      0    -629.04076608  -468.32915814     -0.28527941      2.5e+00    0.0e+00   False   True
# alpha =  0.002
#      6     30      0    -629.10798840  -468.39638046     -0.06722232      2.3e+00    0.0e+00   False   True
# alpha =  0.002
#      7     30      0    -629.11856845  -468.40696051     -0.01058005      2.1e+00    0.0e+00   False   True
# alpha =  0.002
#      8     30      0    -629.12372286  -468.41211492     -0.00515441      1.9e+00    0.0e+00   False   True
# alpha =  0.002
#      9     30      0    -629.12734668  -468.41573874     -0.00362381      1.6e+00    0.0e+00   False   True
# alpha =  0.002
#     10     30      0    -629.12997742  -468.41836948     -0.00263074      1.3e+00    0.0e+00   False   True
# alpha =  0.002
#     11     30      0    -629.13264296  -468.42103502     -0.00266555      1.0e+00    0.0e+00   False   True
# alpha =  0.002
#     12     30      0    -629.13352551  -468.42191757     -0.00088255      8.6e-01    0.0e+00   False   True
# alpha =  0.002
#     13     30      0    -629.13376765  -468.42215971     -0.00024214      7.3e-01    0.0e+00   False   True
# alpha =  0.002
#     14     30      0    -629.13401862  -468.42241068     -0.00025097      5.9e-01    0.0e+00   False   True
# alpha =  0.002
#     15     30      0    -629.13401862  -468.42241068      0.00000000      5.9e-01    0.0e+00   False   True
# alpha =  0.002
#     16     30      0    -629.13401862  -468.42241068      0.00000000      5.9e-01    0.0e+00   False   True
# alpha =  0.002
#     17     30      0    -629.13401862  -468.42241068      0.00000000      5.9e-01    0.0e+00   False   True
# alpha =  0.002
#     18     30      0    -629.13401862  -468.42241068      0.00000000      5.9e-01    0.0e+00   False   True
# alpha =  0.002
#     19     30      0    -629.13401862  -468.42241068      0.00000000      5.9e-01    0.0e+00   False   True
#
#
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
# !!!! Energy is not converging, if you are playing with alpha, is not a good value
# !!!! In any case check orbital and occupation gradients
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
#
#
#
# Lagrage sumdiff 4.2e+00 maxfdiff 6.1e-02
#
# RESULTS OF THE OCCUPATION OPTIMIZATION
# ========================================
#  Idx        n        E (Hartree)
#    1    2.0000000  -58.47582475
#    2    2.0000000  -20.52228501
#    3    2.0000000  -20.51606154
#    4    2.0000000  -20.50985544
#    5    2.0000000   -4.93412922
#    6    2.0000000   -3.22714364
#    7    2.0000000   -3.21983459
#    8    2.0000000   -3.21935751
#    9    2.0000000   -0.96405093
#   10    2.0000000   -0.95605093
#   11    2.0000000   -0.94004173
#   12    2.0000000   -0.92952773
#   13    2.0000000   -0.92638478
#   14    2.0000000   -0.92424831
#   15    2.0000000   -0.62896361
#   16    2.0000000   -0.62890441
#   17    2.0000000   -0.62015305
#   18    2.0000000   -0.52308965
#   19    2.0000000   -0.51613900
#   20    2.0000000   -0.51020367
#   21    0.0000000    0.00000000
#   22    0.0000000    0.00000000
#   23    0.0000000    0.00000000
#   24    0.0000000    0.00000000
#   25    0.0000000    0.00000000
#   26    0.0000000    0.00000000
#   27    0.0000000    0.00000000
#   28    0.0000000    0.00000000
#   29    0.0000000    0.00000000
#   30    0.0000000    0.00000000
#   31    0.0000000    0.00000000
#   32    0.0000000    0.00000000
#   33    0.0000000    0.00000000
#   34    0.0000000    0.00000000
#   35    0.0000000    0.00000000
#   36    0.0000000    0.00000000
#   37    0.0000000    0.00000000
#   38    0.0000000    0.00000000
#   39    0.0000000    0.00000000
#   40    0.0000000    0.00000000
#   41    0.0000000    0.00000000
#   42    0.0000000    0.00000000
#   43    0.0000000    0.00000000
#   44    0.0000000    0.00000000
#   45    0.0000000    0.00000000
#   46    0.0000000    0.00000000
#   47    0.0000000    0.00000000
#   48    0.0000000    0.00000000
#   49    0.0000000    0.00000000
#   50    0.0000000    0.00000000
#   51    0.0000000    0.00000000
#   52    0.0000000    0.00000000
#   53    0.0000000    0.00000000
#   54    0.0000000    0.00000000
#   55    0.0000000    0.00000000
#   56    0.0000000    0.00000000
#   57    0.0000000    0.00000000
#   58    0.0000000    0.00000000
#   59    0.0000000    0.00000000
#   60    0.0000000    0.00000000
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy = {E_nuc + E:15.7f}
#
#
# Elapsed Time:     372.35 (Seconds)
# True
# Number of basis functions                   (NBF)    = 75
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 20
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 2
# Dimension of the Nat. Orb. subspace         (NBF5)   = 60
# No. of electrons                                     = 40
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# HF Calculation (ADAGRAD Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.08
#      0     30      0    -627.64833886  -466.93673092 -10626.64833886      1.8e+01    0.0e+00   False   True
# alpha =  0.08
#      1     30      0    -627.64833886  -466.93673092      0.00000000      1.8e+01    0.0e+00   False   True
# alpha =  0.08
#      2     30      0    -627.64833886  -466.93673092      0.00000000      1.8e+01    0.0e+00   False   True
# alpha =  0.08
#      3     30      0    -627.64833886  -466.93673092      0.00000000      1.8e+01    0.0e+00   False   True
# alpha =  0.08
#      4     30      0    -627.64833886  -466.93673092      0.00000000      1.8e+01    0.0e+00   False   True
# alpha =  0.08
#      5     30      0    -627.64833886  -466.93673092      0.00000000      1.8e+01    0.0e+00   False   True
#
#
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
# !!!! Energy is not converging, if you are playing with alpha, is not a good value
# !!!! In any case check orbital and occupation gradients
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
#
#
#
# Lagrage sumdiff 7.0e+01 maxfdiff 1.3e+00
#
# RESULTS OF THE OCCUPATION OPTIMIZATION
# ========================================
#  Idx        n        E (Hartree)
#    1    2.0000000  -58.15166935
#    2    2.0000000  -19.83590874
#    3    2.0000000  -19.82197968
#    4    2.0000000  -19.80131119
#    5    2.0000000   -4.88954142
#    6    2.0000000   -3.19402253
#    7    2.0000000   -3.18062713
#    8    2.0000000   -3.17623268
#    9    2.0000000   -0.67876562
#   10    2.0000000   -0.66870175
#   11    2.0000000   -0.65830962
#   12    2.0000000   -0.65223326
#   13    2.0000000   -0.63494551
#   14    2.0000000   -0.59611616
#   15    2.0000000   -0.35997292
#   16    2.0000000   -0.35598237
#   17    2.0000000   -0.34518312
#   18    2.0000000   -0.21631293
#   19    2.0000000   -0.20307686
#   20    2.0000000   -0.18241739
#   21    0.0000000    0.00000000
#   22    0.0000000    0.00000000
#   23    0.0000000    0.00000000
#   24    0.0000000    0.00000000
#   25    0.0000000    0.00000000
#   26    0.0000000    0.00000000
#   27    0.0000000    0.00000000
#   28    0.0000000    0.00000000
#   29    0.0000000    0.00000000
#   30    0.0000000    0.00000000
#   31    0.0000000    0.00000000
#   32    0.0000000    0.00000000
#   33    0.0000000    0.00000000
#   34    0.0000000    0.00000000
#   35    0.0000000    0.00000000
#   36    0.0000000    0.00000000
#   37    0.0000000    0.00000000
#   38    0.0000000    0.00000000
#   39    0.0000000    0.00000000
#   40    0.0000000    0.00000000
#   41    0.0000000    0.00000000
#   42    0.0000000    0.00000000
#   43    0.0000000    0.00000000
#   44    0.0000000    0.00000000
#   45    0.0000000    0.00000000
#   46    0.0000000    0.00000000
#   47    0.0000000    0.00000000
#   48    0.0000000    0.00000000
#   49    0.0000000    0.00000000
#   50    0.0000000    0.00000000
#   51    0.0000000    0.00000000
#   52    0.0000000    0.00000000
#   53    0.0000000    0.00000000
#   54    0.0000000    0.00000000
#   55    0.0000000    0.00000000
#   56    0.0000000    0.00000000
#   57    0.0000000    0.00000000
#   58    0.0000000    0.00000000
#   59    0.0000000    0.00000000
#   60    0.0000000    0.00000000
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy = {E_nuc + E:15.7f}
#
#
# Elapsed Time:     127.53 (Seconds)
# True
# Number of basis functions                   (NBF)    = 75
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 20
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 2
# Dimension of the Nat. Orb. subspace         (NBF5)   = 60
# No. of electrons                                     = 40
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# HF Calculation (ADAM Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.02
#      0     30      0    -628.70942236  -467.99781442 -10627.70942236      1.8e+00    0.0e+00   False   True
# alpha =  0.02
#      1     30      0    -629.13643433  -468.42482639     -0.42701196      7.5e-02    0.0e+00   False   True
# alpha =  0.02
#      2     30      0    -629.13644169  -468.42483375     -0.00000736      8.1e-02    0.0e+00   False   True
# alpha =  0.02
#      3     30      0    -629.13644867  -468.42484073     -0.00000698      7.4e-02    0.0e+00   False   True
# alpha =  0.02
#      4     30      0    -629.13644867  -468.42484073      0.00000000      7.4e-02    0.0e+00   False   True
# alpha =  0.02
#      5     30      0    -629.13644867  -468.42484073      0.00000000      7.4e-02    0.0e+00   False   True
# alpha =  0.02
#      6     30      0    -629.13644867  -468.42484073      0.00000000      7.4e-02    0.0e+00   False   True
# alpha =  0.02
#      7     30      0    -629.13644867  -468.42484073      0.00000000      7.4e-02    0.0e+00   False   True
# alpha =  0.02
#      8     30      0    -629.13644867  -468.42484073      0.00000000      7.4e-02    0.0e+00   False   True
#
#
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
# !!!! Energy is not converging, if you are playing with alpha, is not a good value
# !!!! In any case check orbital and occupation gradients
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
#
#
#
# Lagrage sumdiff 7.1e-01 maxfdiff 5.6e-03
#
# RESULTS OF THE OCCUPATION OPTIMIZATION
# ========================================
#  Idx        n        E (Hartree)
#    1    2.0000000  -58.43580886
#    2    2.0000000  -20.48288564
#    3    2.0000000  -20.47521823
#    4    2.0000000  -20.46526606
#    5    2.0000000   -4.94566478
#    6    2.0000000   -3.22759360
#    7    2.0000000   -3.21971615
#    8    2.0000000   -3.21929267
#    9    2.0000000   -0.97773525
#   10    2.0000000   -0.97349444
#   11    2.0000000   -0.96398750
#   12    2.0000000   -0.94855598
#   13    2.0000000   -0.94627646
#   14    2.0000000   -0.94468926
#   15    2.0000000   -0.63211199
#   16    2.0000000   -0.62509241
#   17    2.0000000   -0.61476913
#   18    2.0000000   -0.53437408
#   19    2.0000000   -0.52825046
#   20    2.0000000   -0.51818952
#   21    0.0000000    0.00000000
#   22    0.0000000    0.00000000
#   23    0.0000000    0.00000000
#   24    0.0000000    0.00000000
#   25    0.0000000    0.00000000
#   26    0.0000000    0.00000000
#   27    0.0000000    0.00000000
#   28    0.0000000    0.00000000
#   29    0.0000000    0.00000000
#   30    0.0000000    0.00000000
#   31    0.0000000    0.00000000
#   32    0.0000000    0.00000000
#   33    0.0000000    0.00000000
#   34    0.0000000    0.00000000
#   35    0.0000000    0.00000000
#   36    0.0000000    0.00000000
#   37    0.0000000    0.00000000
#   38    0.0000000    0.00000000
#   39    0.0000000    0.00000000
#   40    0.0000000    0.00000000
#   41    0.0000000    0.00000000
#   42    0.0000000    0.00000000
#   43    0.0000000    0.00000000
#   44    0.0000000    0.00000000
#   45    0.0000000    0.00000000
#   46    0.0000000    0.00000000
#   47    0.0000000    0.00000000
#   48    0.0000000    0.00000000
#   49    0.0000000    0.00000000
#   50    0.0000000    0.00000000
#   51    0.0000000    0.00000000
#   52    0.0000000    0.00000000
#   53    0.0000000    0.00000000
#   54    0.0000000    0.00000000
#   55    0.0000000    0.00000000
#   56    0.0000000    0.00000000
#   57    0.0000000    0.00000000
#   58    0.0000000    0.00000000
#   59    0.0000000    0.00000000
#   60    0.0000000    0.00000000
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy = {E_nuc + E:15.7f}
#
#
# Elapsed Time:     189.69 (Seconds)
# True
